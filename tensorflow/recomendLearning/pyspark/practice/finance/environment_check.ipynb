# %% [markdown]
# ## Environment check

# %%
import yfinance as yf
import sys
import pyspark
import pandas as pd
import os
import torch

# %%
# Expected - 3.10.9
print("Python version:", sys.version)
# Spark - 3.2.1
print("PySpark version:", pyspark.__version__)
# Finance - 0.2.54
print("yahoo finance version: ", yf.__version__)
# pandas - 2.2.2
print("panda version: ", pd.__version__)
# conda env - tensorflowv2
print("conda env: ",os.getenv('CONDA_DEFAULT_ENV'))
# Out:
# Python version: 3.10.14 | packaged by conda-forge | (main, Mar 20 2024, 12:51:49) [Clang 16.0.6 ]
# PySpark version: 3.2.1
# yahoo finance version:  0.2.54
# panda version:  2.2.2
# conda env:  tensorflowv2

# %%
# conda install pytorch::pytorch
print(torch.__version__)
print(torch.cuda.is_available())  # Should print True if CUDA is available
# Out:
# 2.5.1
# False

# %%
# conda install conda-forge::transformers
import transformers
print(transformers.__version__)
# Out:
# 4.49.0

# %%
# conda install -c conda-forge huggingface_hub
import huggingface_hub
print(huggingface_hub.__version__)
# Out:
# 0.24.6

# %%
# conda install -c conda-forge scikit-optimize
import skopt
print(skopt.__version__)
# Out:
# 0.10.2

# %%
# conda install -c conda-forge stable-baselines3
# conda install -c conda-forge gym


import stable_baselines3
import gym
import torch
print(stable_baselines3.__version__)
print("Gym version:", gym.__version__)
print("PyTorch version:", torch.__version__)
# Out:
# 2.5.0
# Gym version: 0.26.1
# PyTorch version: 2.5.1

# %%
# conda install -c conda-forge bayesian-optimization
import bayes_opt
print(bayes_opt.__version__)
# Out:
# 2.0.3

# %%
torch.cuda.is_available()
torch.device("mps")
# Out:
# device(type='mps')

# %%
from bayes_opt import __version__ as bayes_version
print(f"bayes_opt version: {bayes_version}")
print(f"torch version: {torch.__version__}")
print(bayes_opt.__file__)
# Out:
# bayes_opt version: 2.0.3
# torch version: 2.5.1
# /Users/gaurav/miniconda3/envs/tensorflowv2/lib/python3.10/site-packages/bayes_opt/__init__.py
