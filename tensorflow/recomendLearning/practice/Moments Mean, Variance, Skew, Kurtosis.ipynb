# %%
import numpy as np
import matplotlib.pyplot as plt

vals = np.random.normal(0, 10, 10000)

plt.hist(vals, 50)
plt.show()

# %%
np.mean(vals)
# Out:
# -0.07312777819531174

# %%
np.var(vals)
# Out:
# 100.23339614680415

# %%
import scipy.stats as sp
sp.skew(vals)
# Out:
# -0.015275711769883992

# %%
sp.kurtosis(vals)
# Out:
# -0.007138869742707943
