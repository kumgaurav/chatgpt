# %%
from numpy import random
random.seed(0)

totals = {20:0, 30:0, 40:0, 50:0, 60:0, 70:0}
purchases = {20:0, 30:0, 40:0, 50:0, 60:0, 70:0}

totalPurchases = 0
for _ in range(100000):
    ageDecade = random.choice([20,30,40,50,60,70])
    #print('ageDecade : '+str(ageDecade))
    purchaseProbability = float(ageDecade) / 100.0
    totals[ageDecade] += 1
    if(random.random() < purchaseProbability) :
        totalPurchases += 1
        purchases[ageDecade] += 1

# %%
totals
# Out:
# {20: 16576, 30: 16619, 40: 16632, 50: 16805, 60: 16664, 70: 16704}

# %%
purchases
# Out:
# {20: 3392, 30: 4974, 40: 6670, 50: 8319, 60: 9944, 70: 11713}

# %%
totalPurchases
# Out:
# 45012

# %%
PEF = float(purchases[30]) / float(totals[30])
print('P(purchase | 30s) P(E|F): ' + str(PEF))
# Out:
# P(purchase | 30s) P(E|F): 0.29929598652145134

# %%
PF = float(totals[30]) / 100000
print("P(30's): " +  str(PF))
# Out:
# P(30's): 0.16619

# %%
PE = float(totalPurchases)/ 100000.0
print("P(Purchase):" + str(PE))
# Out:
# P(Purchase):0.45012

# %%
print("P(30's, Purchase) P(E,F) : " + str(float(purchases[30]) / 100000.0))
# Out:
# P(30's, Purchase) P(E,F) : 0.04974

# %%
print("P(30's)P(Purchase) P(E)P(F) : " + str(PE * PF))
# Out:
# P(30's)P(Purchase) P(E)P(F) : 0.07480544280000001

# %%
print("P(E|F) = P(E,F)/P(F) : " + str((purchases[30] / 100000.0) / PF))
# Out:
# P(E|F) = P(E,F)/P(F) : 0.29929598652145134

# %%
totals = {20:0, 30:0, 40:0, 50:0, 60:0, 70:0}
purchases = {20:0, 30:0, 40:0, 50:0, 60:0, 70:0}
totalPurchases = 0
for _ in range(100000):
    ageDecade = random.choice([20,30,40,50,60,70])
    #print('ageDecade : '+str(ageDecade))
    purchaseProbability =  0.4
    totals[ageDecade] += 1
    if(random.random() < purchaseProbability) :
        totalPurchases += 1
        purchases[ageDecade] += 1

# %%
PEF = float(purchases[30]) / float(totals[30])
print('P(purchase | 30s) P(E|F): ' + str(PEF))
# Out:
# P(purchase | 30s) P(E|F): 0.397840936813857

# %%
PE = float(totalPurchases)/ 100000.0
print("P(Purchase):" + str(PE))
# Out:
# P(Purchase):0.3984
